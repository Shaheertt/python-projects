# %%
from tkinter import *
from tkinter.ttk import Combobox,Checkbutton

window=Tk()
window.title('calculator')
window.geometry('210x200')

def clicked(numb):
    entry.insert(END,numb)
    
    
def clear2():
    b=entry.get()
    c=len(b)
    entry.delete(c-1,END)
    

    
    
def newfn3():
    newfn2()
    entry.insert(END,v)
    
    
def newfn2():
    global v
    q=entry.get()
    p=str(q)
    m=eval(p)
    v=('=',m)
    return v
def newfn5():
    try:
        newfn3()
    except:
        clear1()
        entry.insert(END,'ERROR')
        

    


entry= Entry(window,width=40)
entry.place(x=0,y=0)


def clear1():
    global entry
    entry=entry.delete(0,END)
    entry=Entry(window,width=40)
    entry.place(x=0,y=0)

btn1= Button(window, text="1",width=5,command=lambda:entry.insert(END,1),fg='red')
btn1.place(x=10,y=30)

btn2= Button(window, text="2",width=5,command=lambda:entry.insert(END,2),fg='red')
btn2.place(x=60,y=30)

btn3= Button(window, text="3",width=5,command=lambda:entry.insert(END,3),fg='red')
btn3.place(x=110,y=30)

btn4= Button(window, text="4",width=5,command=lambda:entry.insert(END,4),fg='red')
btn4.place(x=10,y=60)

btn5= Button(window, text="5",width=5,command=lambda:entry.insert(END,5),fg='red')
btn5.place(x=60,y=60)

btn6= Button(window, text="6",width=5,command=lambda:entry.insert(END,6),fg='red')
btn6.place(x=110,y=60)

btn7= Button(window, text="7",width=5,command=lambda:entry.insert(END,7),fg='red')
btn7.place(x=10,y=90)

btn8= Button(window, text="8",width=5,command=lambda:entry.insert(END,8),fg='red')
btn8.place(x=60,y=90)

btn9= Button(window, text="9",width=5,command=lambda:entry.insert(END,9),fg='red')
btn9.place(x=110,y=90)

btn0= Button(window, text="x",width=5,command=lambda:entry.insert(END,'*'),fg='red',bg='grey')
btn0.place(x=10,y=120)

btns= Button(window, text="0",width=5,command=lambda:entry.insert(END,0),fg='red')
btns.place(x=60,y=120)

btnd= Button(window, text=".",width=5,command=lambda:entry.insert(END,'.'),fg='red')
btnd.place(x=110,y=120)

btnf= Button(window, text="=",width=5,command=newfn5,fg='red',bg='grey')
btnf.place(x=160,y=120)

btng= Button(window, text="c",width=5,command=clear2,fg='red',bg='grey')
btng.place(x=160,y=30)

btnh= Button(window, text="/",width=5,command=lambda:entry.insert(END,'/'),fg='red',bg='grey')
btnh.place(x=160,y=60)

btnj= Button(window, text="+",width=5,command=lambda:entry.insert(END,'+'),fg='red',bg='grey')
btnj.place(x=160,y=90)

btnk= Button(window, text="-",width=5,command=lambda:entry.insert(END,'-'),fg='red',bg='grey')
btnk.place(x=10,y=150)

btnl= Button(window, text="Ac",width=5,command=clear1,fg='red',bg='grey')
btnl.place(x=60,y=150)












window.mainloop()

# %%
z='10+5-2'
x=eval(z)

# %%
x
# Out:
# 13
