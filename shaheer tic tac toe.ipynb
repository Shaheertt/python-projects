# %%
 
p=input('enter name of player1:')
q=input('enter name of player2:')

import random
a=[p,q]
b=random.choice(a)
current_player=b

d={7:" ",8:" ",9:" ",
   4:" ",5:" ",6:" ",
   1:" ",2:" ",3:" "}

dic1={p:'X',q:'O'}

def board(d):
    print(f"{d[7]} | {d[8]} | {d[9]}")
    print('--','--','--','-',)
    print(f"{d[4]} | {d[5]} | {d[6]}")
    print('--','--','--','-',)
    print(f"{d[1]} | {d[2]} | {d[3]}")

def enternumber():
    global s
    while True:
        s=input('enter a number betweeen 1 and 9:')
        if s=='1' or s=='8' or s=='2' or s=='3' or s=='4' or s=='5' or s=='6' or s=='7' or s=='9':
            s=int(s)
            if d[s] == 'X' or d[s] == 'O':
                pass
            else:
                break
        else:
            pass           
            
def position():            
    if current_player==p:
        d[s]=dic1[p]
        print(d[s])
    else:
        d[s]=dic1[q]
        print(d[s])

def currentplayers():
    global current_player
    if current_player==p:
        current_player=q
    else:
        current_player=p

def checking():
    global gameover
    gameover=False
    if d[7]==d[8]==d[9]=='X' or d[7]==d[8]==d[9]=='O':
        print('winner =',b)
        gameover=True
    elif d[4]==d[5]==d[6]=='X' or d[4]==d[5]==d[6]=='O':
        print('winner =',b)
        gameover=True
    elif d[1]==d[2]==d[3]=='X' or d[1]==d[2]==d[3]=='O':
        print('winner =',b)
        gameover=True
    elif d[7]==d[4]==d[1]=='X' or d[7]==d[4]==d[1]=='O':
        print('winner =',b)
        gameover=True
    elif d[8]==d[5]==d[2]=='X' or d[8]==d[5]==d[2]=='O':
        print('winner =',b)
        gameover=True
    elif d[9]==d[6]==d[3]=='X' or d[9]==d[6]==d[3]=='O':
        print('winner =',b)
        gameover=True
    elif d[7]==d[5]==d[3]=='X' or d[7]==d[5]==d[3]=='O':
        print('winner =',b)
        gameover=True
    elif d[1]==d[5]==d[9]=='X' or d[1]==d[5]==d[9]=='O':
        print('winner =',b)
        gameover=True
    else:
        return
        
enternumber()
position()
board(d)

while True:
    currentplayers()
    enternumber()
    position()
    board(d)
    checking()
    if gameover==True:
        break
# Out:
# enter name of player1:shaheer
# enter name of player2:s
# enter a number betweeen 1 and 9:1
# O
#   |   |
# -- -- -- -
#   |   |
# -- -- -- -
# O |   |
# enter a number betweeen 1 and 9:2
# X
#   |   |
# -- -- -- -
#   |   |
# -- -- -- -
# O | X |
# enter a number betweeen 1 and 9:3
# O
#   |   |
# -- -- -- -
#   |   |
# -- -- -- -
# O | X | O
# enter a number betweeen 1 and 9:5
# X
#   |   |
# -- -- -- -
#   | X |
# -- -- -- -
# O | X | O
# enter a number betweeen 1 and 9:7
# O
# O |   |
# -- -- -- -
#   | X |
# -- -- -- -
# O | X | O
# enter a number betweeen 1 and 9:8
# X
# O | X |
# -- -- -- -
#   | X |
# -- -- -- -
# O | X | O
# winner = s
