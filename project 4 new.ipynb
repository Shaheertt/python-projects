# %%
from tkinter import *
from tkinter.ttk import Combobox,Checkbutton,Progressbar,Frame,Notebook,Radiobutton
from tkinter import filedialog,Menu

window=Tk()
window.title('QUIZ')
window.geometry('600x350')

def clicked():
    selected.get()
    print(text)
    
label=Label(window)
label.pack()
    

def newfns():
    selection =str(selected.get())
    label.config(text = selection)
    
    
d={1:'Asia',2:'Asia',3:'Pacific Ocean',4:'1945',5:'Greenland'}





def newfn7():
    global count
    global e
    count=0
    if str(selected.get())==d[1]:
        count+=1
    if str(selected1.get())==d[2]:
        count+=1
    if str(selected2.get())==d[3]:
        count+=1
    if str(selected3.get())==d[4]:
        count+=1
    if str(selected4.get())==d[5]:
        count+=1
    e=('total score is',count)
    entry1.insert(END,count)
    buttons.config(state="disabled")
    
    
    
    

            
        

tab_control=Notebook(window)
tab1=Frame(tab_control)
tab2=Frame(tab_control)
tab3=Frame(tab_control)
tab4=Frame(tab_control)
tab5=Frame(tab_control)
tab6=Frame(tab_control)


tab_control.add(tab1,text='Q1')
tab_control.add(tab2,text='Q2')
tab_control.add(tab3,text='Q3')
tab_control.add(tab4,text='Q4')
tab_control.add(tab5,text='Q5')
tab_control.add(tab6,text='Result')



label1=Label(tab1,text='1.There are seven continents in the world. In terms of area, the largest continent is _____.',fg='black',bg='white')

label1.pack()
selected=StringVar()


rad1=Radiobutton(tab1,text='Asia',value='Asia',variable=selected,command=newfns)
rad2=Radiobutton(tab1,text='Africa',value='Africa',variable=selected,command=newfns)
rad3=Radiobutton(tab1,text='Australia',value='Australia',variable=selected,command=newfns)
rad4=Radiobutton(tab1,text='Antartica',value='Antartica',variable=selected,command=newfns)

rad1.pack()
rad2.pack()
rad3.pack()
rad4.pack()



button=Button(tab1,text='Next',bg='yellow')
button.pack()


label2=Label(tab2,text='2.In terms of population, the largest continent is _____.',fg='black',bg='white')
label2.pack()
selected1=StringVar()


rad5=Radiobutton(tab2,text='Asia',value='Asia',variable=selected1,command=newfns)
rad6=Radiobutton(tab2,text='Africa',value='Africa',variable=selected1,command=newfns)
rad7=Radiobutton(tab2,text='Antartica',value='Antartica',variable=selected1,command=newfns)
rad8=Radiobutton(tab2,text='Europe',value='Europe',variable=selected1,command=newfns)

rad5.pack()
rad6.pack()
rad7.pack()
rad8.pack()


button=Button(tab2,text='Next',bg='yellow')
button.pack()


label3=Label(tab3,text='3.There are five oceans in the world. The largest ocean is _____.',fg='black',bg='white')
label3.pack()
selected2=StringVar()

rad9=Radiobutton(tab3,text='Pacific Ocean',value='Pacific Ocean',variable=selected2,command=newfns)
rad10=Radiobutton(tab3,text='Atlantic Ocean',value='Atlantic Ocean',variable=selected2,command=newfns)
rad11=Radiobutton(tab3,text='Indian Ocean',value='Indian Ocean',variable=selected2,command=newfns)
rad12=Radiobutton(tab3,text='Artic Ocean',value='Artic Ocean',variable=selected2,command=newfns)

rad9.pack()
rad10.pack()
rad11.pack()
rad12.pack()


button=Button(tab3,text='Next',bg='yellow')
button.pack()

label4=Label(tab4,text='4.United Nations was formed on 24 October _____ in the United States',fg='black',bg='white')
label4.pack()
selected3=StringVar()

rad13=Radiobutton(tab4,text='1946',value='1946',variable=selected3,command=newfns)
rad14=Radiobutton(tab4,text='1947',value='1947',variable=selected3,command=newfns)
rad15=Radiobutton(tab4,text='1944',value='1944',variable=selected3,command=newfns)
rad16=Radiobutton(tab4,text='1945',value='1945',variable=selected3,command=newfns)

rad13.pack()
rad14.pack()
rad15.pack()
rad16.pack()


button=Button(tab4,text='Next',bg='yellow')
button.pack()

label5=Label(tab5,text='5.the largest island in the world is ',fg='black',bg='white')
label5.pack()
selected4=StringVar()





rad17=Radiobutton(tab5,text='New zealand',value='New zealand',variable=selected4,command=newfns)
rad18=Radiobutton(tab5,text='Srilanka',value='Srilanka',variable=selected4,command=newfns)
rad19=Radiobutton(tab5,text='Iceland',value='Iceland',variable=selected4,command=newfns)
rad20=Radiobutton(tab5,text='Greenland',value='Greenland',variable=selected4,command=newfns)

rad17.pack()
rad18.pack()
rad19.pack()
rad20.pack()


button=Button(tab5,text='Next',bg='yellow')
button.pack()



buttons=Button(tab6,text='check Result',command=newfn7,fg='blue')
buttons.pack()




entry1= Entry(tab6,width=5)
entry1.place(x=300,y=30)


def clicked(numb):
    entry.insert(END,numb)
    
label5=Label(tab6,text='total score out of 5 is')
label5.place(x=180,y=30)

    

    

    
























tab_control.pack(expand=89,fill='both')
window.mainloop()
