# %%
a=input('enter the name of the player:')
d='computer'


def choose():
    import random
    b=(0,1,2,3,4,5,6)
    c=random.choice(b)
    return c
choose()


import random
e=[a,d]
f=random.choice(e)
print(f) 


current_player=f


def choosen(): 
    global g
    global i
    if f==a:
        g=input('batting or bowling:')
        if g=='batting':
            print(a,'has choosen to bat first')
        else:
            print(a,'has choosen to bowl first')
    else:
        h=['batting','bowling']
        i=random.choice(h)
        print('computer has decided',i,'first')

        
        
def entering():
    global j
    global l
    global total
    global i
    total=0
    while True:
        if g=='batting':
            j=input('enter the number between 0 to 6:')
            if j=='0' or j=='1' or j=='2' or j=='3' or j=='4' or j=='5' or j=='6':
                j=int(j)
                print(j)
                l=choose()
                print(l)
                total=total+j
                if j==l:
                    total=total-j
                    print('out')
                    print('total score of',a,'=',total)
                    break
                else:
                    print('current score of',a,'is',total)
                
        
        else:
            pass
        
        
def entering1():
    global j
    global l
    global total
    global i
    total=0
    while True:
        if i=='bowling':
            j=input('enter the number between 0 to 6:')
            if j=='0' or j=='1' or j=='2' or j=='3' or j=='4' or j=='5' or j=='6':
                j=int(j)
                print(j)
                l=choose()
                print(l)
                total=total+j
                if j==l:
                    total=total-j
                    print('out')
                    print('total score of',a,'=',total)
                    break
                else:
                    print('current score of',a,'is',total)
            
        else:
            pass





    


        
def currentplayers():
    global current_player
    if current_player==a:
        current_player=d
    else:
        current_player=a
        
        
        

        
        
def entering2():
    global x
    global y
    global total2
    global g
    total2=0
    while True:
        if i=='batting':
            x=input('enter the number between 0 to 6:')
            if x=='0' or x=='1' or x=='2' or x=='3' or x=='4' or x=='5' or x=='6':
                x=int(x)
                print(x)
                y=choose()
                print(y)
                total2=total2+y
                if x==y:
                    total2=total2-y
                    print('out')
                    print('total score of computer=',total2)
                    break
                else:
                    print('current score of computer=',total2)
            else:
                pass
            
            
            
            
            
            
def entering4():
    global x
    global y
    global total2
    global g
    total2=0
    while True:
        if g=='bowling':
            x=input('enter the number between 0 to 6:')
            if x=='0' or x=='1' or x=='2' or x=='3' or x=='4' or x=='5' or x=='6':
                x=int(x)
                print(x)
                y=choose()
                print(y)
                total2=total2+y
                if x==y:
                    total2=total2-y
                    print('out')
                    print('total score of computer=',total2)
                    break
                else:
                    print('current score of computer=',total2)
                    
            
        else:
            pass

    
   

 
    
def jumble():
    if g=='batting':
        entering()
        print()
        print('second batting')
        print()
        secondbatting()
        entering9()
        
        
    elif g=='bowling':
        entering4()
        print()
        print('second batting')
        print()
        secondbatting3()
        entering6()
        
        
    else:
        pass
    
def jumble2():    
    if i=='batting':
        entering2()
        print()
        print('second batting')
        print()
        secondbatting1()
        entering7()
    
        
    elif i=='bowling':
        entering1()
        print()
        print('second batting')
        print()
        secondbatting2()
        entering8()
        
        
    else:
        pass
        
        
def secondbatting():
    global g
    if g=='batting':
        g='bowling'
    else:
        pass
def secondbatting1():
    global i
    if i=='batting':
        i='bowling'
    else:
        pass        
def secondbatting2():
    global i
    if i=='bowling':
        i='batting'
    else:
        pass        
def secondbatting3():
    global g
    if g=='bowling':
        g='batting'
    else:
        pass        
        
        
        
def jumbles():
    if f==a:
        jumble()
    else:
        jumble2()
        
        
        
        
def computing():
    if g=='batting':
        if total>total2:
            print(a,'won')
            global should_break
            should_break = True
        else:
            pass
        
def computing2():
    if i=='bowling':
        if total>total2:
            print(a,'won')
            global should_break
            should_break = True
        else:
            pass
        
    
def computing1():    
    if i=='batting':
        if total2>total:
            print('computer won')
            global should_break
            should_break = True
        else:
            pass
        
def computing3():    
    if g=='bowling':
        if total2>total:
            print('computer won')
            global should_break
            should_break = True
            
        else:
            pass
        
def entering6():
    global j
    global l
    global total
    global i
    total=0
    while True:
        if g=='batting':
            j=input('enter the number between 0 to 6:')
            if j=='0' or j=='1' or j=='2' or j=='3' or j=='4' or j=='5' or j=='6':
                j=int(j)
                print(j)
                l=choose()
                print(l)
                total=total+j
                if j==l:
                    total=total-j
                    print('out')
                    print('total score of',a,'=',total)
                    newfn()
                    break
                else:
                    should_break = False
                    computing()
                    if should_break==True:
                        break
                    print('current score of',a,'is',total)
                
        
        else:
            pass
        
        
def entering7():
    global j
    global l
    global total
    global i
    total=0
    while True:
        if i=='bowling':
            j=input('enter the number between 0 to 6:')
            if j=='0' or j=='1' or j=='2' or j=='3' or j=='4' or j=='5' or j=='6':
                j=int(j)
                print(j)
                l=choose()
                print(l)
                total=total+j
                if j==l:
                    total=total-j
                    print('out')
                    print('total score of',a,'=',total)
                    newfn()
                    break
                else:
                    should_break = False
                    computing2()
                    if should_break==True:
                        break
                    print('current score of',a,'is',total)
        else:
            pass
        
        
def entering8():
    global x
    global y
    global total2
    global g
    total2=0
    while True:
        if i=='batting':
            x=input('enter the number between 0 to 6:')
            if x=='0' or x=='1' or x=='2' or x=='3' or x=='4' or x=='5' or x=='6':
                x=int(x)
                print(x)
                y=choose()
                print(y)
                total2=total2+y
                if x==y:
                    total2=total2-y
                    print('out')
                    print('total score of computer=',total2)
                    newfn()
                    break
                else:
                    should_break = False
                    computing1()
                    if should_break==True:
                        break
                    print('current score of computer=',total2)
                    
            else:
                pass
            
            
            
            
            
            
def entering9():
    global x
    global y
    global total2
    global g
    total2=0
    while True:
        if g=='bowling':
            x=input('enter the number between 0 to 6:')
            if x=='0' or x=='1' or x=='2' or x=='3' or x=='4' or x=='5' or x=='6':
                x=int(x)
                print(x)
                y=choose()
                print(y)
                total2=total2+y
                if x==y:
                    total2=total2-y
                    print('out')
                    print('total score of computer=',total2)
                    newfn()
                    break
                else:
                    should_break = False
                    computing3()
                    if should_break==True:
                        break
                    print('current score of computer=',total2)
            
        else:
            pass

def newfn():
    if total2>total:
        print('computer won')
    elif total==total2:
        print('tie')
    elif total>total2:
        print(a,'won')
    else:    
        pass

            
        
        
        
choosen()
jumbles()
# Out:
# enter the name of the player:msk
# computer
# computer has decided bowling first
# enter the number between 0 to 6:6
# 6
# 2
# current score of msk is 6
